# %%
import os
import json
import pandas as pd
import traceback

# %%
from langchain_openai import ChatOpenAI

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
KEY = os.getenv("OPENAI_API_KEY")

# %%
print(KEY)
# Out:
# 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

# %%
llm = ChatOpenAI(openai_api_key=KEY, model='gpt-3.5-turbo', temperature=0.2)

# %%
llm
# Out:
# ChatOpenAI(profile={'max_input_tokens': 16385, 'max_output_tokens': 4096, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x7eab3c281db0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7eab3b39b760>, root_client=<openai.OpenAI object at 0x7eab3c282290>, root_async_client=<openai.AsyncOpenAI object at 0x7eab3b39b6a0>, temperature=0.2, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
from langchain_openai import OpenAI
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import LLMChain
from langchain_classic.chains import SequentialChain
from langchain_community.callbacks import get_openai_callback
import PyPDF2

# %%
TEMPLATE = """

"""

# %%
quiz_generation_prompt = PromptTemplate(
    input_variables= ['text', 'number', 'subject', 'tone', 'response_json' ],
    template= TEMPLATE
)
